# %%
# !nvidia-smi
# Out:
# Sat Jul  6 21:41:37 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 537.42                 Driver Version: 537.42       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1060 6GB  WDDM  | 00000000:01:00.0  On |                  N/A |
# |  0%   47C    P8               9W / 200W |   1710MiB /  6144MiB |      8%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1224    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A      1788    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A      6872    C+G   ...al\Discord\app-1.0.9152\Discord.exe    N/A      |
# |    0   N/A  N/A      7972      C   ...IDIA RTX Voice\NVIDIA RTX Voice.exe    N/A      |
# |    0   N/A  N/A      9812    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A      9972    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     10004    C+G   ...on\126.0.2592.87\msedgewebview2.exe    N/A      |
# |    0   N/A  N/A     10080    C+G   ...2txyewy\StartMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     10836    C+G   ...al\Discord\app-1.0.9152\Discord.exe    N/A      |
# |    0   N/A  N/A     12328    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A     13304    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     13444    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     15264    C+G   ...\Nitro\Pro\13\nitro_pro_systray.exe    N/A      |
# |    0   N/A  N/A     16844    C+G   ...inaries\Win64\EpicGamesLauncher.exe    N/A      |
# |    0   N/A  N/A     17492    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     19648    C+G   ...ne\Binaries\Win64\EpicWebHelper.exe    N/A      |
# |    0   N/A  N/A     19904    C+G   ...Programs\Microsoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     21400    C+G   ...6.0_x64__cv1g1gvanyjgm\WhatsApp.exe    N/A      |
# |    0   N/A  N/A     22764    C+G   ...pdnekdrzrea0\XboxGameBarSpotify.exe    N/A      |
# |    0   N/A  N/A     23084    C+G   ...__8wekyb3d8bbwe\Notepad\Notepad.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install transformers 
# !pip install tf-keras
# Out:
# Requirement already satisfied: transformers in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (4.39.3)
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: filelock in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sriram\appdata\roaming\python\python312\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\sriram\appdata\roaming\python\python312\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2024.2.2)
# Collecting tf-keras
#   Downloading tf_keras-2.16.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tf-keras) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in c:\users\sriram\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (1.62.2)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.2.1)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.43.0)
# Requirement already satisfied: rich in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sriram\appdata\roaming\python\python312\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sriram\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf-keras) (0.1.2)
# Downloading tf_keras-2.16.0-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.7 MB 325.1 kB/s eta 0:00:06
#    - -------------------------------------- 0.1/1.7 MB 409.6 kB/s eta 0:00:05
#    -- ------------------------------------- 0.1/1.7 MB 595.3 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.7 MB 908.0 kB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.7 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.5/1.7 MB 1.7 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.7 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.4 MB/s eta 0:00:00
# Installing collected packages: tf-keras
# Successfully installed tf-keras-2.16.0
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from transformers import pipeline

# %%
sentimentModel1=pipeline("sentiment-analysis",model="cardiffnlp/twitter-roberta-base-sentiment-latest",tokenizer="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# Some layers of TFRobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest and are newly initialized: ['classifier']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
sentimentModel12=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# c:\Users\sriram\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:148: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sriram\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
sentimentModel1("You are good")
# Out:
# [{'label': 'neutral', 'score': 0.3753618001937866}]

# %%
sentimentModel12("Univeristy is baaaaaadass")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9928452372550964}]

# %%
sentimentModel13=pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english",tokenizer="siebert/sentiment-roberta-large-english")
# Out:
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at siebert/sentiment-roberta-large-english.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
sentimentModel13(["This Anime is okayish.And bad anime i ever seen","bad"])
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9994834661483765},
#  {'label': 'NEGATIVE', 'score': 0.9990259408950806}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from ast import List
import pandas as pd
from transformers import pipeline
import sys
import os

# %%
sys.path.append('D:/Ml projects/AnimeProject/Anime-Recommendation/Data_Preparation/AnimeDataScrapper')
from AniScrapper import AniScrappers
sys.path.append('D:/Ml projects/AnimeProject/Anime-Recommendation/Data_Preprocessing')
from pre_processing import PreProcess

# %%
from score_generation import ScoreGeneration

# %%
m=PreProcess().preprocess_Reddit_comments(AniScrappers("One Piece").fetchReviewFrom("all"))
print(m[0:3])
# Out:
# One Piece
# 0               content completely skip filler instead
# 1        agreed good decision switch piece anime manga
# 2    piece kingdom 2 series screw anime adaptation ...
# Name: Review, dtype: object

# %%
r=ScoreGeneration()
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
print(r.animeListCommentsScore(["thsi ig good"]))
# Out:
# bye
# [{'label': 'POSITIVE', 'score': 0.9984012246131897}]
# 0.998

# %%
print(r.animeListCommentsScore(m.tolist()))
# Out:
# bye
# [{'label': 'NEGATIVE', 'score': 0.9977186918258667}]
# [{'label': 'POSITIVE', 'score': 0.9981095790863037}]
# [{'label': 'NEGATIVE', 'score': 0.9994654059410095}]
# [{'label': 'NEGATIVE', 'score': 0.9994978904724121}]
# [{'label': 'POSITIVE', 'score': 0.9979420304298401}]
# [{'label': 'NEGATIVE', 'score': 0.9991878867149353}]
# [{'label': 'NEGATIVE', 'score': 0.9993706345558167}]
# [{'label': 'POSITIVE', 'score': 0.9982638955116272}]
# [{'label': 'NEGATIVE', 'score': 0.9950107336044312}]
# [{'label': 'POSITIVE', 'score': 0.9987209439277649}]
# [{'label': 'POSITIVE', 'score': 0.9983262419700623}]
# [{'label': 'NEGATIVE', 'score': 0.999496340751648}]
# [{'label': 'POSITIVE', 'score': 0.9930110573768616}]
# [{'label': 'POSITIVE', 'score': 0.9953357577323914}]
# [{'label': 'POSITIVE', 'score': 0.997841477394104}]
# [{'label': 'NEGATIVE', 'score': 0.9951179027557373}]
# [{'label': 'POSITIVE', 'score': 0.9967643022537231}]
# [{'label': 'POSITIVE', 'score': 0.9980746507644653}]
# [{'label': 'POSITIVE', 'score': 0.9986935257911682}]
# [{'label': 'NEGATIVE', 'score': 0.9966049194335938}]
# [{'label': 'POSITIVE', 'score': 0.988440990447998}]
# [{'label': 'POSITIVE', 'score': 0.9758869409561157}]
# [{'label': 'POSITIVE', 'score': 0.9862650036811829}]
# [{'label': 'NEGATIVE', 'score': 0.9924613833427429}]
# [{'label': 'NEGATIVE', 'score': 0.999454915523529}]
# [{'label': 'NEGATIVE', 'score': 0.9983225464820862}]
# [{'label': 'POSITIVE', 'score': 0.9981606602668762}]
# [{'label': 'NEGATIVE', 'score': 0.9989528656005859}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'POSITIVE', 'score': 0.9925833940505981}]
# [{'label': 'POSITIVE', 'score': 0.9984488487243652}]
# [{'label': 'NEGATIVE', 'score': 0.9691196084022522}]
# [{'label': 'NEGATIVE', 'score': 0.9987712502479553}]
# [{'label': 'POSITIVE', 'score': 0.9982163310050964}]
# [{'label': 'POSITIVE', 'score': 0.9978317618370056}]
# [{'label': 'POSITIVE', 'score': 0.9983999133110046}]
# [{'label': 'NEGATIVE', 'score': 0.9994909763336182}]
# [{'label': 'NEGATIVE', 'score': 0.9924395084381104}]
# [{'label': 'POSITIVE', 'score': 0.9980378746986389}]
# [{'label': 'NEGATIVE', 'score': 0.9677553772926331}]
# [{'label': 'NEGATIVE', 'score': 0.9994783997535706}]
# [{'label': 'NEGATIVE', 'score': 0.9980565905570984}]
# [{'label': 'NEGATIVE', 'score': 0.9992538094520569}]
# [{'label': 'NEGATIVE', 'score': 0.9994576573371887}]
# [{'label': 'POSITIVE', 'score': 0.998584508895874}]
# [{'label': 'NEGATIVE', 'score': 0.9993719458580017}]
# [{'label': 'NEGATIVE', 'score': 0.9994964599609375}]
# [{'label': 'NEGATIVE', 'score': 0.9980801343917847}]
# [{'label': 'POSITIVE', 'score': 0.9968940019607544}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'NEGATIVE', 'score': 0.9945747256278992}]
# [{'label': 'NEGATIVE', 'score': 0.9993614554405212}]
# [{'label': 'POSITIVE', 'score': 0.9985985159873962}]
# [{'label': 'NEGATIVE', 'score': 0.9993271827697754}]
# [{'label': 'POSITIVE', 'score': 0.9986280202865601}]
# [{'label': 'POSITIVE', 'score': 0.9988030195236206}]
# [{'label': 'NEGATIVE', 'score': 0.9986513257026672}]
# [{'label': 'NEGATIVE', 'score': 0.9989506006240845}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'NEGATIVE', 'score': 0.9887598752975464}]
# [{'label': 'POSITIVE', 'score': 0.996616542339325}]
# [{'label': 'POSITIVE', 'score': 0.9941800832748413}]
# [{'label': 'POSITIVE', 'score': 0.9854311943054199}]
# [{'label': 'NEGATIVE', 'score': 0.9993809461593628}]
# [{'label': 'NEGATIVE', 'score': 0.9984788298606873}]
# [{'label': 'POSITIVE', 'score': 0.9987848401069641}]
# [{'label': 'NEGATIVE', 'score': 0.9993742108345032}]
# [{'label': 'NEGATIVE', 'score': 0.9994799494743347}]
# [{'label': 'POSITIVE', 'score': 0.9985377788543701}]
# [{'label': 'NEGATIVE', 'score': 0.9994797110557556}]
# [{'label': 'NEGATIVE', 'score': 0.9994251728057861}]
# [{'label': 'POSITIVE', 'score': 0.9979358911514282}]
# [{'label': 'NEGATIVE', 'score': 0.9994521737098694}]
# [{'label': 'POSITIVE', 'score': 0.9983308911323547}]
# [{'label': 'POSITIVE', 'score': 0.9981381893157959}]
# [{'label': 'POSITIVE', 'score': 0.9959665536880493}]
# [{'label': 'NEGATIVE', 'score': 0.9994972944259644}]
# [{'label': 'NEGATIVE', 'score': 0.9969122409820557}]
# [{'label': 'NEGATIVE', 'score': 0.9920645356178284}]
# [{'label': 'POSITIVE', 'score': 0.9808094501495361}]
# [{'label': 'POSITIVE', 'score': 0.9960487484931946}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'NEGATIVE', 'score': 0.9994884729385376}]
# [{'label': 'POSITIVE', 'score': 0.9985482096672058}]
# [{'label': 'POSITIVE', 'score': 0.9963909983634949}]
# [{'label': 'POSITIVE', 'score': 0.9951345324516296}]
# [{'label': 'POSITIVE', 'score': 0.9952337145805359}]
# [{'label': 'NEGATIVE', 'score': 0.9994423985481262}]
# [{'label': 'POSITIVE', 'score': 0.9976843595504761}]
# [{'label': 'NEGATIVE', 'score': 0.996967613697052}]
# [{'label': 'POSITIVE', 'score': 0.9983084201812744}]
# [{'label': 'POSITIVE', 'score': 0.9784316420555115}]
# [{'label': 'POSITIVE', 'score': 0.9982306361198425}]
# [{'label': 'POSITIVE', 'score': 0.9784036874771118}]
# [{'label': 'NEGATIVE', 'score': 0.9991611242294312}]
# [{'label': 'NEGATIVE', 'score': 0.9950182437896729}]
# [{'label': 'NEGATIVE', 'score': 0.9994862079620361}]
# [{'label': 'POSITIVE', 'score': 0.9978033900260925}]
# [{'label': 'POSITIVE', 'score': 0.9979056119918823}]
# [{'label': 'NEGATIVE', 'score': 0.6629716157913208}]
# [{'label': 'POSITIVE', 'score': 0.9828709363937378}]
# [{'label': 'NEGATIVE', 'score': 0.6284207701683044}]
# [{'label': 'NEGATIVE', 'score': 0.9976062774658203}]
# [{'label': 'NEGATIVE', 'score': 0.9723605513572693}]
# [{'label': 'NEGATIVE', 'score': 0.5266432762145996}]
# [{'label': 'NEGATIVE', 'score': 0.9865564703941345}]
# [{'label': 'NEGATIVE', 'score': 0.9973475933074951}]
# [{'label': 'NEGATIVE', 'score': 0.9893679022789001}]
# [{'label': 'NEGATIVE', 'score': 0.9992916584014893}]
# [{'label': 'NEGATIVE', 'score': 0.9994308352470398}]
# [{'label': 'POSITIVE', 'score': 0.9988968372344971}]
# [{'label': 'POSITIVE', 'score': 0.9868310689926147}]
# [{'label': 'POSITIVE', 'score': 0.7696974277496338}]
# [{'label': 'POSITIVE', 'score': 0.9972139000892639}]
# [{'label': 'NEGATIVE', 'score': 0.9989677667617798}]
# [{'label': 'POSITIVE', 'score': 0.9757722020149231}]
# [{'label': 'NEGATIVE', 'score': 0.9994550347328186}]
# [{'label': 'POSITIVE', 'score': 0.9983444213867188}]
# [{'label': 'POSITIVE', 'score': 0.9897204041481018}]
# [{'label': 'POSITIVE', 'score': 0.9855687022209167}]
# [{'label': 'POSITIVE', 'score': 0.9876564741134644}]
# [{'label': 'NEGATIVE', 'score': 0.9978731870651245}]
# [{'label': 'NEGATIVE', 'score': 0.9935747981071472}]
# [{'label': 'NEGATIVE', 'score': 0.99662846326828}]
# [{'label': 'NEGATIVE', 'score': 0.9913824200630188}]
# [{'label': 'NEGATIVE', 'score': 0.9992490410804749}]
# [{'label': 'POSITIVE', 'score': 0.8015191555023193}]
# [{'label': 'POSITIVE', 'score': 0.9969874024391174}]
# [{'label': 'NEGATIVE', 'score': 0.9969334602355957}]
# [{'label': 'POSITIVE', 'score': 0.9853851199150085}]
# [{'label': 'POSITIVE', 'score': 0.9855431318283081}]
# [{'label': 'POSITIVE', 'score': 0.998490571975708}]
# [{'label': 'NEGATIVE', 'score': 0.9875258207321167}]
# [{'label': 'NEGATIVE', 'score': 0.999466598033905}]
# [{'label': 'NEGATIVE', 'score': 0.9891665577888489}]
# [{'label': 'NEGATIVE', 'score': 0.6902182102203369}]
# [{'label': 'POSITIVE', 'score': 0.6862402558326721}]
# [{'label': 'POSITIVE', 'score': 0.9984807372093201}]
# [{'label': 'POSITIVE', 'score': 0.9978474378585815}]
# [{'label': 'NEGATIVE', 'score': 0.9983512163162231}]
# [{'label': 'NEGATIVE', 'score': 0.688831627368927}]
# [{'label': 'POSITIVE', 'score': 0.9974894523620605}]
# [{'label': 'POSITIVE', 'score': 0.998105525970459}]
# [{'label': 'POSITIVE', 'score': 0.9952583909034729}]
# [{'label': 'POSITIVE', 'score': 0.9981153011322021}]
# [{'label': 'NEGATIVE', 'score': 0.9845102429389954}]
# [{'label': 'NEGATIVE', 'score': 0.9966733455657959}]
# [{'label': 'NEGATIVE', 'score': 0.9915876984596252}]
# [{'label': 'POSITIVE', 'score': 0.9948261380195618}]
# [{'label': 'NEGATIVE', 'score': 0.9897494912147522}]
# [{'label': 'NEGATIVE', 'score': 0.993074893951416}]
# [{'label': 'POSITIVE', 'score': 0.9975124597549438}]
# [{'label': 'POSITIVE', 'score': 0.9981287121772766}]
# [{'label': 'POSITIVE', 'score': 0.9988086223602295}]
# [{'label': 'NEGATIVE', 'score': 0.9983595013618469}]
# [{'label': 'POSITIVE', 'score': 0.9882013201713562}]
# [{'label': 'POSITIVE', 'score': 0.8129287958145142}]
# [{'label': 'NEGATIVE', 'score': 0.9951307773590088}]
# [{'label': 'POSITIVE', 'score': 0.9986283779144287}]
# [{'label': 'NEGATIVE', 'score': 0.9992998838424683}]
# [{'label': 'NEGATIVE', 'score': 0.9951307773590088}]
# [{'label': 'NEGATIVE', 'score': 0.9177616834640503}]
# [{'label': 'POSITIVE', 'score': 0.9986720085144043}]
# [{'label': 'POSITIVE', 'score': 0.9893044233322144}]
# [{'label': 'NEGATIVE', 'score': 0.9349372982978821}]
# [{'label': 'NEGATIVE', 'score': 0.9985312223434448}]
# [{'label': 'NEGATIVE', 'score': 0.9899649024009705}]
# [{'label': 'NEGATIVE', 'score': 0.997364342212677}]
# [{'label': 'POSITIVE', 'score': 0.9782868027687073}]
# [{'label': 'NEGATIVE', 'score': 0.993994414806366}]
# [{'label': 'NEGATIVE', 'score': 0.9942796230316162}]
# [{'label': 'POSITIVE', 'score': 0.9968603849411011}]
# [{'label': 'POSITIVE', 'score': 0.931998074054718}]
# [{'label': 'NEGATIVE', 'score': 0.9918345212936401}]
# [{'label': 'NEGATIVE', 'score': 0.9951307773590088}]
# [{'label': 'NEGATIVE', 'score': 0.9923985600471497}]
# [{'label': 'NEGATIVE', 'score': 0.9958464503288269}]
# [{'label': 'NEGATIVE', 'score': 0.9940138459205627}]
# [{'label': 'NEGATIVE', 'score': 0.9954882264137268}]
# [{'label': 'NEGATIVE', 'score': 0.6496652960777283}]
# [{'label': 'POSITIVE', 'score': 0.9972148537635803}]
# [{'label': 'NEGATIVE', 'score': 0.9986109733581543}]
# [{'label': 'POSITIVE', 'score': 0.997808039188385}]
# [{'label': 'NEGATIVE', 'score': 0.9988178610801697}]
# [{'label': 'POSITIVE', 'score': 0.5623553991317749}]
# [{'label': 'NEGATIVE', 'score': 0.9089304208755493}]
# [{'label': 'NEGATIVE', 'score': 0.9975969195365906}]
# [{'label': 'POSITIVE', 'score': 0.7220656275749207}]
# [{'label': 'POSITIVE', 'score': 0.9967419505119324}]
# [{'label': 'POSITIVE', 'score': 0.995633065700531}]
# [{'label': 'NEGATIVE', 'score': 0.9994245767593384}]
# [{'label': 'POSITIVE', 'score': 0.9981721639633179}]
# [{'label': 'NEGATIVE', 'score': 0.5622917413711548}]
# [{'label': 'POSITIVE', 'score': 0.998508870601654}]
# [{'label': 'POSITIVE', 'score': 0.9936375617980957}]
# [{'label': 'NEGATIVE', 'score': 0.990922749042511}]
# [{'label': 'POSITIVE', 'score': 0.9850966334342957}]
# [{'label': 'POSITIVE', 'score': 0.9918373227119446}]
# [{'label': 'NEGATIVE', 'score': 0.9866047501564026}]
# [{'label': 'NEGATIVE', 'score': 0.9979952573776245}]
# [{'label': 'POSITIVE', 'score': 0.9968554973602295}]
# [{'label': 'POSITIVE', 'score': 0.9935624599456787}]
# [{'label': 'POSITIVE', 'score': 0.9810106158256531}]
# [{'label': 'POSITIVE', 'score': 0.9901394248008728}]
# [{'label': 'NEGATIVE', 'score': 0.9963250756263733}]
# [{'label': 'NEGATIVE', 'score': 0.9981325268745422}]
# [{'label': 'NEGATIVE', 'score': 0.9740672707557678}]
# [{'label': 'POSITIVE', 'score': 0.9978678226470947}]
# [{'label': 'POSITIVE', 'score': 0.9383475184440613}]
# [{'label': 'NEGATIVE', 'score': 0.9884872436523438}]
# [{'label': 'POSITIVE', 'score': 0.9979896545410156}]
# [{'label': 'NEGATIVE', 'score': 0.9994348883628845}]
# [{'label': 'NEGATIVE', 'score': 0.9908921122550964}]
# [{'label': 'POSITIVE', 'score': 0.975627601146698}]
# [{'label': 'POSITIVE', 'score': 0.9904090166091919}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'NEGATIVE', 'score': 0.9976668357849121}]
# [{'label': 'NEGATIVE', 'score': 0.9990535378456116}]
# [{'label': 'POSITIVE', 'score': 0.9940250515937805}]
# [{'label': 'POSITIVE', 'score': 0.9940250515937805}]
# [{'label': 'POSITIVE', 'score': 0.9973674416542053}]
# [{'label': 'NEGATIVE', 'score': 0.9770821928977966}]
# [{'label': 'POSITIVE', 'score': 0.993478536605835}]
# [{'label': 'NEGATIVE', 'score': 0.9990234375}]
# [{'label': 'NEGATIVE', 'score': 0.9989907145500183}]
# [{'label': 'NEGATIVE', 'score': 0.9981328845024109}]
# [{'label': 'POSITIVE', 'score': 0.9945260882377625}]
# [{'label': 'NEGATIVE', 'score': 0.9441521763801575}]
# [{'label': 'NEGATIVE', 'score': 0.9980624318122864}]
# [{'label': 'POSITIVE', 'score': 0.9984378218650818}]
# [{'label': 'NEGATIVE', 'score': 0.9993987083435059}]
# [{'label': 'NEGATIVE', 'score': 0.9398857355117798}]
# [{'label': 'POSITIVE', 'score': 0.99730384349823}]
# [{'label': 'NEGATIVE', 'score': 0.9017138481140137}]
# [{'label': 'NEGATIVE', 'score': 0.9975205063819885}]
# [{'label': 'NEGATIVE', 'score': 0.994468092918396}]
# [{'label': 'POSITIVE', 'score': 0.9978876709938049}]
# [{'label': 'NEGATIVE', 'score': 0.9960117340087891}]
# [{'label': 'POSITIVE', 'score': 0.9936529397964478}]
# [{'label': 'NEGATIVE', 'score': 0.9516960978507996}]
# [{'label': 'POSITIVE', 'score': 0.985602080821991}]
# [{'label': 'NEGATIVE', 'score': 0.9964516162872314}]
# [{'label': 'NEGATIVE', 'score': 0.996322512626648}]
# [{'label': 'NEGATIVE', 'score': 0.9959999322891235}]
# [{'label': 'NEGATIVE', 'score': 0.9911504983901978}]
# [{'label': 'NEGATIVE', 'score': 0.9989926218986511}]
# [{'label': 'POSITIVE', 'score': 0.9983958601951599}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'NEGATIVE', 'score': 0.9970740079879761}]
# [{'label': 'POSITIVE', 'score': 0.99050372838974}]
# [{'label': 'NEGATIVE', 'score': 0.9978081583976746}]
# [{'label': 'NEGATIVE', 'score': 0.9986911416053772}]
# [{'label': 'NEGATIVE', 'score': 0.9983192086219788}]
# [{'label': 'NEGATIVE', 'score': 0.9994588494300842}]
# [{'label': 'NEGATIVE', 'score': 0.9991023540496826}]
# [{'label': 'NEGATIVE', 'score': 0.9940350651741028}]
# [{'label': 'POSITIVE', 'score': 0.9984720349311829}]
# [{'label': 'NEGATIVE', 'score': 0.9978740215301514}]
# [{'label': 'NEGATIVE', 'score': 0.9981740713119507}]
# [{'label': 'NEGATIVE', 'score': 0.9993327260017395}]
# [{'label': 'POSITIVE', 'score': 0.9981434345245361}]
# [{'label': 'NEGATIVE', 'score': 0.9994427561759949}]
# [{'label': 'NEGATIVE', 'score': 0.9993089437484741}]
# [{'label': 'NEGATIVE', 'score': 0.9972467422485352}]
# [{'label': 'NEGATIVE', 'score': 0.9988923668861389}]
# [{'label': 'NEGATIVE', 'score': 0.9907616972923279}]
# [{'label': 'NEGATIVE', 'score': 0.9943987727165222}]
# [{'label': 'POSITIVE', 'score': 0.9908331036567688}]
# [{'label': 'NEGATIVE', 'score': 0.9994688630104065}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'NEGATIVE', 'score': 0.9953633546829224}]
# [{'label': 'POSITIVE', 'score': 0.9852796792984009}]
# [{'label': 'NEGATIVE', 'score': 0.9970218539237976}]
# [{'label': 'NEGATIVE', 'score': 0.9984001517295837}]
# [{'label': 'POSITIVE', 'score': 0.9976170063018799}]
# [{'label': 'POSITIVE', 'score': 0.9986518025398254}]
# [{'label': 'NEGATIVE', 'score': 0.9951540231704712}]
# [{'label': 'NEGATIVE', 'score': 0.9941885471343994}]
# [{'label': 'POSITIVE', 'score': 0.9970090985298157}]
# [{'label': 'NEGATIVE', 'score': 0.9978106617927551}]
# [{'label': 'POSITIVE', 'score': 0.9982017278671265}]
# [{'label': 'POSITIVE', 'score': 0.9984140396118164}]
# [{'label': 'NEGATIVE', 'score': 0.9977560639381409}]
# [{'label': 'POSITIVE', 'score': 0.9889743328094482}]
# [{'label': 'POSITIVE', 'score': 0.9984320998191833}]
# [{'label': 'POSITIVE', 'score': 0.9984904527664185}]
# [{'label': 'POSITIVE', 'score': 0.9986120462417603}]
# [{'label': 'POSITIVE', 'score': 0.9980798959732056}]
# [{'label': 'NEGATIVE', 'score': 0.9982486963272095}]
# [{'label': 'POSITIVE', 'score': 0.9978772401809692}]
# [{'label': 'NEGATIVE', 'score': 0.9989155530929565}]
# [{'label': 'NEGATIVE', 'score': 0.9993488192558289}]
# [{'label': 'POSITIVE', 'score': 0.988902747631073}]
# [{'label': 'POSITIVE', 'score': 0.9988968372344971}]
# [{'label': 'POSITIVE', 'score': 0.9983296990394592}]
# [{'label': 'NEGATIVE', 'score': 0.9966795444488525}]
# [{'label': 'NEGATIVE', 'score': 0.9955106973648071}]
# [{'label': 'NEGATIVE', 'score': 0.9663387537002563}]
# [{'label': 'POSITIVE', 'score': 0.9980902075767517}]
# [{'label': 'POSITIVE', 'score': 0.9950320720672607}]
# [{'label': 'POSITIVE', 'score': 0.9977777600288391}]
# [{'label': 'POSITIVE', 'score': 0.997517466545105}]
# [{'label': 'POSITIVE', 'score': 0.9986067414283752}]
# [{'label': 'POSITIVE', 'score': 0.993137776851654}]
# [{'label': 'POSITIVE', 'score': 0.9960850477218628}]
# [{'label': 'POSITIVE', 'score': 0.9981358051300049}]
# [{'label': 'POSITIVE', 'score': 0.9942367076873779}]
# [{'label': 'POSITIVE', 'score': 0.9938606023788452}]
# [{'label': 'NEGATIVE', 'score': 0.9994377493858337}]
# [{'label': 'NEGATIVE', 'score': 0.9990594983100891}]
# [{'label': 'NEGATIVE', 'score': 0.9807192087173462}]
# [{'label': 'NEGATIVE', 'score': 0.975397527217865}]
# [{'label': 'NEGATIVE', 'score': 0.9968005418777466}]
# [{'label': 'POSITIVE', 'score': 0.9976354837417603}]
# [{'label': 'POSITIVE', 'score': 0.9976674914360046}]
# [{'label': 'POSITIVE', 'score': 0.99744713306427}]
# [{'label': 'POSITIVE', 'score': 0.9975689053535461}]
# [{'label': 'POSITIVE', 'score': 0.9981061220169067}]
# [{'label': 'POSITIVE', 'score': 0.9983966946601868}]
# [{'label': 'NEGATIVE', 'score': 0.9994049072265625}]
# [{'label': 'NEGATIVE', 'score': 0.9988991022109985}]
# [{'label': 'NEGATIVE', 'score': 0.9883375763893127}]
# [{'label': 'NEGATIVE', 'score': 0.9235791563987732}]
# [{'label': 'POSITIVE', 'score': 0.9983628392219543}]
# [{'label': 'POSITIVE', 'score': 0.9978808760643005}]
# [{'label': 'NEGATIVE', 'score': 0.8727026581764221}]
# [{'label': 'NEGATIVE', 'score': 0.9917387366294861}]
# [{'label': 'NEGATIVE', 'score': 0.98862224817276}]
# [{'label': 'NEGATIVE', 'score': 0.9977664947509766}]
# [{'label': 'NEGATIVE', 'score': 0.9993751645088196}]
# [{'label': 'NEGATIVE', 'score': 0.9994387030601501}]
# [{'label': 'NEGATIVE', 'score': 0.9983671307563782}]
# [{'label': 'POSITIVE', 'score': 0.9978998899459839}]
# [{'label': 'POSITIVE', 'score': 0.9966027736663818}]
# [{'label': 'NEGATIVE', 'score': 0.9990604519844055}]
# [{'label': 'POSITIVE', 'score': 0.9982510209083557}]
# [{'label': 'POSITIVE', 'score': 0.9979427456855774}]
# [{'label': 'POSITIVE', 'score': 0.9919374585151672}]
# [{'label': 'POSITIVE', 'score': 0.9980900883674622}]
# [{'label': 'POSITIVE', 'score': 0.9843594431877136}]
# [{'label': 'POSITIVE', 'score': 0.9836174249649048}]
# [{'label': 'NEGATIVE', 'score': 0.9946191310882568}]
# [{'label': 'NEGATIVE', 'score': 0.9991905093193054}]
# [{'label': 'NEGATIVE', 'score': 0.9992431402206421}]
# [{'label': 'NEGATIVE', 'score': 0.9975923895835876}]
# [{'label': 'NEGATIVE', 'score': 0.9966921806335449}]
# [{'label': 'NEGATIVE', 'score': 0.9993934631347656}]
# [{'label': 'NEGATIVE', 'score': 0.9934285283088684}]
# [{'label': 'NEGATIVE', 'score': 0.9994966983795166}]
# [{'label': 'NEGATIVE', 'score': 0.997724711894989}]
# [{'label': 'POSITIVE', 'score': 0.9968794584274292}]
# [{'label': 'POSITIVE', 'score': 0.9967779517173767}]
# [{'label': 'NEGATIVE', 'score': 0.9948915243148804}]
# [{'label': 'NEGATIVE', 'score': 0.9976105690002441}]
# [{'label': 'POSITIVE', 'score': 0.9893859624862671}]
# [{'label': 'POSITIVE', 'score': 0.995223343372345}]
# [{'label': 'POSITIVE', 'score': 0.9978918433189392}]
# [{'label': 'POSITIVE', 'score': 0.9983919262886047}]
# [{'label': 'NEGATIVE', 'score': 0.9961934089660645}]
# [{'label': 'NEGATIVE', 'score': 0.9964739680290222}]
# [{'label': 'POSITIVE', 'score': 0.9802924990653992}]
# [{'label': 'POSITIVE', 'score': 0.9898231625556946}]
# [{'label': 'NEGATIVE', 'score': 0.7859076261520386}]
# [{'label': 'NEGATIVE', 'score': 0.9982069730758667}]
# [{'label': 'POSITIVE', 'score': 0.9863759875297546}]
# [{'label': 'POSITIVE', 'score': 0.9957846999168396}]
# [{'label': 'NEGATIVE', 'score': 0.9973944425582886}]
# [{'label': 'POSITIVE', 'score': 0.9965830445289612}]
# [{'label': 'NEGATIVE', 'score': 0.9978012442588806}]
# [{'label': 'POSITIVE', 'score': 0.9935705661773682}]
# [{'label': 'NEGATIVE', 'score': 0.9923787117004395}]
# [{'label': 'NEGATIVE', 'score': 0.9916257262229919}]
# [{'label': 'NEGATIVE', 'score': 0.9884436726570129}]
# [{'label': 'POSITIVE', 'score': 0.9866504669189453}]
# [{'label': 'NEGATIVE', 'score': 0.9933403134346008}]
# [{'label': 'NEGATIVE', 'score': 0.9994937181472778}]
# [{'label': 'POSITIVE', 'score': 0.9975219368934631}]
# [{'label': 'POSITIVE', 'score': 0.998714804649353}]
# [{'label': 'POSITIVE', 'score': 0.9977163076400757}]
# [{'label': 'POSITIVE', 'score': 0.9980280995368958}]
# [{'label': 'POSITIVE', 'score': 0.996654748916626}]
# [{'label': 'NEGATIVE', 'score': 0.9939711689949036}]
# [{'label': 'POSITIVE', 'score': 0.9765378832817078}]
# [{'label': 'NEGATIVE', 'score': 0.9927927255630493}]
# [{'label': 'NEGATIVE', 'score': 0.998080849647522}]
# [{'label': 'NEGATIVE', 'score': 0.999338686466217}]
# [{'label': 'POSITIVE', 'score': 0.9878262877464294}]
# [{'label': 'NEGATIVE', 'score': 0.995798647403717}]
# [{'label': 'POSITIVE', 'score': 0.99747234582901}]
# [{'label': 'POSITIVE', 'score': 0.8430107831954956}]
# [{'label': 'NEGATIVE', 'score': 0.9971828460693359}]
# [{'label': 'POSITIVE', 'score': 0.9984375834465027}]
# [{'label': 'POSITIVE', 'score': 0.9982268214225769}]
# [{'label': 'NEGATIVE', 'score': 0.9994776844978333}]
# [{'label': 'NEGATIVE', 'score': 0.9911120533943176}]
# [{'label': 'NEGATIVE', 'score': 0.9994487166404724}]
# [{'label': 'NEGATIVE', 'score': 0.9964330196380615}]
# [{'label': 'NEGATIVE', 'score': 0.9994701743125916}]
# [{'label': 'POSITIVE', 'score': 0.9979249238967896}]
# [{'label': 'NEGATIVE', 'score': 0.9994519352912903}]
# [{'label': 'POSITIVE', 'score': 0.9760876893997192}]
# [{'label': 'NEGATIVE', 'score': 0.9990226030349731}]
# [{'label': 'NEGATIVE', 'score': 0.9675132632255554}]
# [{'label': 'NEGATIVE', 'score': 0.9988366961479187}]
# [{'label': 'NEGATIVE', 'score': 0.9880226850509644}]
# [{'label': 'NEGATIVE', 'score': 0.9982232451438904}]
# [{'label': 'NEGATIVE', 'score': 0.9714625477790833}]
# [{'label': 'NEGATIVE', 'score': 0.9993882179260254}]
# [{'label': 'NEGATIVE', 'score': 0.9680199027061462}]
# [{'label': 'POSITIVE', 'score': 0.9911367893218994}]
# [{'label': 'NEGATIVE', 'score': 0.9782017469406128}]
# [{'label': 'NEGATIVE', 'score': 0.9910780787467957}]
# [{'label': 'POSITIVE', 'score': 0.9853615164756775}]
# [{'label': 'POSITIVE', 'score': 0.997998058795929}]
# [{'label': 'NEGATIVE', 'score': 0.9906086921691895}]
# [{'label': 'POSITIVE', 'score': 0.9888052940368652}]
# [{'label': 'POSITIVE', 'score': 0.9837945103645325}]
# [{'label': 'POSITIVE', 'score': 0.9943676590919495}]
# [{'label': 'POSITIVE', 'score': 0.9946521520614624}]
# [{'label': 'NEGATIVE', 'score': 0.9991492033004761}]
# [{'label': 'NEGATIVE', 'score': 0.9146032929420471}]
# [{'label': 'NEGATIVE', 'score': 0.999462902545929}]
# [{'label': 'NEGATIVE', 'score': 0.9975312352180481}]
# [{'label': 'NEGATIVE', 'score': 0.9994613528251648}]
# [{'label': 'POSITIVE', 'score': 0.9984965324401855}]
# [{'label': 'POSITIVE', 'score': 0.9789493083953857}]
# [{'label': 'NEGATIVE', 'score': 0.9842560887336731}]
# [{'label': 'NEGATIVE', 'score': 0.9971083998680115}]
# [{'label': 'NEGATIVE', 'score': 0.9964300990104675}]
# [{'label': 'POSITIVE', 'score': 0.9895738959312439}]
# [{'label': 'NEGATIVE', 'score': 0.9953560829162598}]
# [{'label': 'POSITIVE', 'score': 0.9907003045082092}]
# [{'label': 'NEGATIVE', 'score': 0.9923930168151855}]
# [{'label': 'POSITIVE', 'score': 0.9947078227996826}]
# [{'label': 'POSITIVE', 'score': 0.9986658096313477}]
# [{'label': 'POSITIVE', 'score': 0.9917426705360413}]
# [{'label': 'POSITIVE', 'score': 0.9986155033111572}]
# [{'label': 'POSITIVE', 'score': 0.9981220364570618}]
# [{'label': 'NEGATIVE', 'score': 0.9905915856361389}]
# [{'label': 'POSITIVE', 'score': 0.9968727231025696}]
# [{'label': 'NEGATIVE', 'score': 0.9917536973953247}]
# [{'label': 'POSITIVE', 'score': 0.9975265860557556}]
# [{'label': 'POSITIVE', 'score': 0.9896816611289978}]
# [{'label': 'POSITIVE', 'score': 0.9938905239105225}]
# [{'label': 'NEGATIVE', 'score': 0.9936010241508484}]
# [{'label': 'NEGATIVE', 'score': 0.9989211559295654}]
# [{'label': 'POSITIVE', 'score': 0.9980283379554749}]
# [{'label': 'NEGATIVE', 'score': 0.9993257522583008}]
# [{'label': 'POSITIVE', 'score': 0.9927197694778442}]
# [{'label': 'NEGATIVE', 'score': 0.9982089996337891}]
# [{'label': 'POSITIVE', 'score': 0.9972795844078064}]
# [{'label': 'NEGATIVE', 'score': 0.999367892742157}]
# [{'label': 'NEGATIVE', 'score': 0.9967735409736633}]
# [{'label': 'POSITIVE', 'score': 0.9829533100128174}]
# [{'label': 'NEGATIVE', 'score': 0.9993834495544434}]
# [{'label': 'NEGATIVE', 'score': 0.9993983507156372}]
# [{'label': 'NEGATIVE', 'score': 0.9952103495597839}]
# [{'label': 'NEGATIVE', 'score': 0.9576202630996704}]
# [{'label': 'NEGATIVE', 'score': 0.9847931861877441}]
# [{'label': 'POSITIVE', 'score': 0.9930174350738525}]
# [{'label': 'NEGATIVE', 'score': 0.9932389259338379}]
# [{'label': 'POSITIVE', 'score': 0.9979013204574585}]
# [{'label': 'POSITIVE', 'score': 0.9788564443588257}]
# [{'label': 'NEGATIVE', 'score': 0.9962965846061707}]
# [{'label': 'POSITIVE', 'score': 0.9979829788208008}]
# [{'label': 'POSITIVE', 'score': 0.9932559728622437}]
# [{'label': 'POSITIVE', 'score': 0.9944887161254883}]
# [{'label': 'NEGATIVE', 'score': 0.987235963344574}]
# [{'label': 'NEGATIVE', 'score': 0.9993160963058472}]
# [{'label': 'NEGATIVE', 'score': 0.9894285798072815}]
# [{'label': 'POSITIVE', 'score': 0.9847099184989929}]
# [{'label': 'NEGATIVE', 'score': 0.9782017469406128}]
# [{'label': 'POSITIVE', 'score': 0.99226975440979}]
# [{'label': 'POSITIVE', 'score': 0.9985349178314209}]
# [{'label': 'POSITIVE', 'score': 0.9969279170036316}]
# [{'label': 'POSITIVE', 'score': 0.9825683832168579}]
# [{'label': 'POSITIVE', 'score': 0.9833793044090271}]
# [{'label': 'POSITIVE', 'score': 0.998741090297699}]
# [{'label': 'NEGATIVE', 'score': 0.9921392798423767}]
# [{'label': 'POSITIVE', 'score': 0.9978243112564087}]
# [{'label': 'NEGATIVE', 'score': 0.9966256618499756}]
# [{'label': 'POSITIVE', 'score': 0.9985867738723755}]
# [{'label': 'POSITIVE', 'score': 0.9968538880348206}]
# [{'label': 'NEGATIVE', 'score': 0.9939217567443848}]
# [{'label': 'POSITIVE', 'score': 0.9982637763023376}]
# [{'label': 'NEGATIVE', 'score': 0.9961554408073425}]
# [{'label': 'NEGATIVE', 'score': 0.9994279742240906}]
# [{'label': 'POSITIVE', 'score': 0.9985211491584778}]
# [{'label': 'POSITIVE', 'score': 0.9984689354896545}]
# [{'label': 'POSITIVE', 'score': 0.9986704587936401}]
# [{'label': 'POSITIVE', 'score': 0.996623158454895}]
# [{'label': 'POSITIVE', 'score': 0.9983252882957458}]
# [{'label': 'NEGATIVE', 'score': 0.9826512932777405}]
# [{'label': 'NEGATIVE', 'score': 0.9961297512054443}]
# [{'label': 'POSITIVE', 'score': 0.9985798597335815}]
# [{'label': 'POSITIVE', 'score': 0.9864873290061951}]
# [{'label': 'POSITIVE', 'score': 0.9972793459892273}]
# [{'label': 'POSITIVE', 'score': 0.9293339848518372}]
# [{'label': 'NEGATIVE', 'score': 0.9992939233779907}]
# [{'label': 'POSITIVE', 'score': 0.9975510239601135}]
# [{'label': 'POSITIVE', 'score': 0.9981260895729065}]
# [{'label': 'POSITIVE', 'score': 0.9959942102432251}]
# [{'label': 'POSITIVE', 'score': 0.9951683282852173}]
# [{'label': 'NEGATIVE', 'score': 0.9835520386695862}]
# [{'label': 'NEGATIVE', 'score': 0.9967589974403381}]
# [{'label': 'POSITIVE', 'score': 0.9899287819862366}]
# [{'label': 'NEGATIVE', 'score': 0.9977320432662964}]
# [{'label': 'POSITIVE', 'score': 0.9987584352493286}]
# [{'label': 'POSITIVE', 'score': 0.9983475208282471}]
# [{'label': 'NEGATIVE', 'score': 0.9943932294845581}]
# [{'label': 'NEGATIVE', 'score': 0.9994807839393616}]
# [{'label': 'NEGATIVE', 'score': 0.9991000890731812}]
# [{'label': 'POSITIVE', 'score': 0.9902352690696716}]
# [{'label': 'POSITIVE', 'score': 0.9947530031204224}]
# [{'label': 'POSITIVE', 'score': 0.9987849593162537}]
# [{'label': 'NEGATIVE', 'score': 0.9991896748542786}]
# [{'label': 'NEGATIVE', 'score': 0.9920744895935059}]
# [{'label': 'POSITIVE', 'score': 0.998055100440979}]
# [{'label': 'POSITIVE', 'score': 0.9957636594772339}]
# [{'label': 'NEGATIVE', 'score': 0.9987902045249939}]
# [{'label': 'POSITIVE', 'score': 0.9862521290779114}]
# [{'label': 'NEGATIVE', 'score': 0.9994015693664551}]
# [{'label': 'POSITIVE', 'score': 0.9629316329956055}]
# [{'label': 'POSITIVE', 'score': 0.9628149271011353}]
# [{'label': 'POSITIVE', 'score': 0.9966279864311218}]
# [{'label': 'NEGATIVE', 'score': 0.9900575280189514}]
# [{'label': 'POSITIVE', 'score': 0.9987002611160278}]
# [{'label': 'POSITIVE', 'score': 0.9980284571647644}]
# [{'label': 'NEGATIVE', 'score': 0.9994334578514099}]
# [{'label': 'NEGATIVE', 'score': 0.9978349804878235}]
# [{'label': 'POSITIVE', 'score': 0.9982624650001526}]
# [{'label': 'NEGATIVE', 'score': 0.9979019165039062}]
# [{'label': 'NEGATIVE', 'score': 0.996545135974884}]
# [{'label': 'POSITIVE', 'score': 0.990760087966919}]
# [{'label': 'NEGATIVE', 'score': 0.9953815937042236}]
# [{'label': 'NEGATIVE', 'score': 0.9938806295394897}]
# [{'label': 'POSITIVE', 'score': 0.9914976954460144}]
# [{'label': 'POSITIVE', 'score': 0.998106837272644}]
# [{'label': 'POSITIVE', 'score': 0.9912769794464111}]
# [{'label': 'POSITIVE', 'score': 0.997550904750824}]
# [{'label': 'POSITIVE', 'score': 0.998746395111084}]
# [{'label': 'NEGATIVE', 'score': 0.991523265838623}]
# [{'label': 'NEGATIVE', 'score': 0.997647225856781}]
# [{'label': 'NEGATIVE', 'score': 0.9895215034484863}]
# [{'label': 'POSITIVE', 'score': 0.9936733245849609}]
# [{'label': 'POSITIVE', 'score': 0.9988623857498169}]
# [{'label': 'NEGATIVE', 'score': 0.9820910096168518}]
# [{'label': 'NEGATIVE', 'score': 0.999492883682251}]
# [{'label': 'POSITIVE', 'score': 0.9970222115516663}]
# [{'label': 'POSITIVE', 'score': 0.9984540939331055}]
# [{'label': 'POSITIVE', 'score': 0.9967679977416992}]
# [{'label': 'NEGATIVE', 'score': 0.9970930814743042}]
# [{'label': 'POSITIVE', 'score': 0.9971122741699219}]
# [{'label': 'NEGATIVE', 'score': 0.9978081583976746}]
# [{'label': 'NEGATIVE', 'score': 0.9993438124656677}]
# [{'label': 'NEGATIVE', 'score': 0.9973242282867432}]
# [{'label': 'NEGATIVE', 'score': 0.9994837045669556}]
# [{'label': 'NEGATIVE', 'score': 0.9994261264801025}]
# [{'label': 'POSITIVE', 'score': 0.9848419427871704}]
# [{'label': 'NEGATIVE', 'score': 0.997258186340332}]
# [{'label': 'NEGATIVE', 'score': 0.9992164373397827}]
# [{'label': 'POSITIVE', 'score': 0.9987928867340088}]
# [{'label': 'NEGATIVE', 'score': 0.9938231706619263}]
# [{'label': 'POSITIVE', 'score': 0.9981502294540405}]
# [{'label': 'POSITIVE', 'score': 0.9950526356697083}]
# [{'label': 'NEGATIVE', 'score': 0.988920271396637}]
# [{'label': 'NEGATIVE', 'score': 0.998198926448822}]
# [{'label': 'NEGATIVE', 'score': 0.9917105436325073}]
# [{'label': 'POSITIVE', 'score': 0.9986095428466797}]
# [{'label': 'NEGATIVE', 'score': 0.9980599284172058}]
# [{'label': 'POSITIVE', 'score': 0.9987449645996094}]
# [{'label': 'POSITIVE', 'score': 0.9956687688827515}]
# [{'label': 'POSITIVE', 'score': 0.998518168926239}]
# [{'label': 'POSITIVE', 'score': 0.9985764026641846}]
# [{'label': 'NEGATIVE', 'score': 0.8788789510726929}]
# [{'label': 'NEGATIVE', 'score': 0.9981470108032227}]
# [{'label': 'NEGATIVE', 'score': 0.9983648657798767}]
# [{'label': 'POSITIVE', 'score': 0.9979891777038574}]
# [{'label': 'NEGATIVE', 'score': 0.9978142976760864}]
# [{'label': 'POSITIVE', 'score': 0.971855878829956}]
# [{'label': 'POSITIVE', 'score': 0.9867152571678162}]
# [{'label': 'NEGATIVE', 'score': 0.9834553003311157}]
# [{'label': 'NEGATIVE', 'score': 0.9993891716003418}]
# [{'label': 'NEGATIVE', 'score': 0.9904770851135254}]
# [{'label': 'NEGATIVE', 'score': 0.99935382604599}]
# [{'label': 'NEGATIVE', 'score': 0.99945467710495}]
# [{'label': 'NEGATIVE', 'score': 0.9929123520851135}]
# [{'label': 'NEGATIVE', 'score': 0.9984737038612366}]
# [{'label': 'POSITIVE', 'score': 0.9968825578689575}]
# [{'label': 'NEGATIVE', 'score': 0.9986441731452942}]
# [{'label': 'POSITIVE', 'score': 0.9981123208999634}]
# [{'label': 'POSITIVE', 'score': 0.9966525435447693}]
# [{'label': 'NEGATIVE', 'score': 0.9985400438308716}]
# [{'label': 'POSITIVE', 'score': 0.9954883456230164}]
# [{'label': 'POSITIVE', 'score': 0.9981650710105896}]
# [{'label': 'NEGATIVE', 'score': 0.9883071780204773}]
# [{'label': 'NEGATIVE', 'score': 0.99722820520401}]
# [{'label': 'POSITIVE', 'score': 0.9966621398925781}]
# [{'label': 'POSITIVE', 'score': 0.9891284108161926}]
# [{'label': 'NEGATIVE', 'score': 0.9993883371353149}]
# [{'label': 'POSITIVE', 'score': 0.9984949827194214}]
# [{'label': 'POSITIVE', 'score': 0.996992826461792}]
# [{'label': 'POSITIVE', 'score': 0.9846644997596741}]
# [{'label': 'NEGATIVE', 'score': 0.9992026686668396}]
# [{'label': 'POSITIVE', 'score': 0.9980213642120361}]
# [{'label': 'POSITIVE', 'score': 0.9911490678787231}]
# [{'label': 'NEGATIVE', 'score': 0.997549831867218}]
# [{'label': 'NEGATIVE', 'score': 0.9993271827697754}]
# [{'label': 'POSITIVE', 'score': 0.9984742999076843}]
# [{'label': 'NEGATIVE', 'score': 0.985822856426239}]
# [{'label': 'POSITIVE', 'score': 0.9865103363990784}]
# [{'label': 'NEGATIVE', 'score': 0.9993534684181213}]
# [{'label': 'POSITIVE', 'score': 0.9893273115158081}]
# [{'label': 'NEGATIVE', 'score': 0.9994458556175232}]
# [{'label': 'NEGATIVE', 'score': 0.9975194334983826}]
# [{'label': 'POSITIVE', 'score': 0.9702592492103577}]
# [{'label': 'NEGATIVE', 'score': 0.994472324848175}]
# [{'label': 'POSITIVE', 'score': 0.9970201849937439}]
# [{'label': 'POSITIVE', 'score': 0.9967254400253296}]
# [{'label': 'NEGATIVE', 'score': 0.9869959354400635}]
# [{'label': 'POSITIVE', 'score': 0.9956369996070862}]
# [{'label': 'POSITIVE', 'score': 0.9846919178962708}]
# [{'label': 'POSITIVE', 'score': 0.9979861974716187}]
# [{'label': 'POSITIVE', 'score': 0.996107280254364}]
# [{'label': 'POSITIVE', 'score': 0.9963250756263733}]
# [{'label': 'NEGATIVE', 'score': 0.9992117881774902}]
# [{'label': 'NEGATIVE', 'score': 0.9994874000549316}]
# [{'label': 'NEGATIVE', 'score': 0.9994770884513855}]
# [{'label': 'POSITIVE', 'score': 0.9986095428466797}]
# [{'label': 'POSITIVE', 'score': 0.996535062789917}]
# [{'label': 'NEGATIVE', 'score': 0.9921519756317139}]
# [{'label': 'NEGATIVE', 'score': 0.9977368116378784}]
# [{'label': 'NEGATIVE', 'score': 0.9973944425582886}]
# [{'label': 'NEGATIVE', 'score': 0.9989176988601685}]
# [{'label': 'NEGATIVE', 'score': 0.9950194358825684}]
# [{'label': 'POSITIVE', 'score': 0.9888138175010681}]
# [{'label': 'NEGATIVE', 'score': 0.999446451663971}]
# [{'label': 'NEGATIVE', 'score': 0.9951776266098022}]
# [{'label': 'NEGATIVE', 'score': 0.9919557571411133}]
# [{'label': 'NEGATIVE', 'score': 0.9939036965370178}]
# [{'label': 'POSITIVE', 'score': 0.9987909197807312}]
# [{'label': 'NEGATIVE', 'score': 0.9970880150794983}]
# [{'label': 'NEGATIVE', 'score': 0.9983392953872681}]
# [{'label': 'NEGATIVE', 'score': 0.9993294477462769}]
# [{'label': 'POSITIVE', 'score': 0.9972123503684998}]
# [{'label': 'NEGATIVE', 'score': 0.9894310235977173}]
# [{'label': 'NEGATIVE', 'score': 0.9994602799415588}]
# [{'label': 'POSITIVE', 'score': 0.988172709941864}]
# [{'label': 'POSITIVE', 'score': 0.9968137145042419}]
# [{'label': 'POSITIVE', 'score': 0.9978684186935425}]
# [{'label': 'NEGATIVE', 'score': 0.9994826316833496}]
# [{'label': 'POSITIVE', 'score': 0.9950297474861145}]
# [{'label': 'NEGATIVE', 'score': 0.9948400855064392}]
# [{'label': 'NEGATIVE', 'score': 0.9990259408950806}]
# [{'label': 'POSITIVE', 'score': 0.9984527826309204}]
# [{'label': 'POSITIVE', 'score': 0.9833621382713318}]
# [{'label': 'NEGATIVE', 'score': 0.9903857707977295}]
# [{'label': 'NEGATIVE', 'score': 0.9992727637290955}]
# [{'label': 'NEGATIVE', 'score': 0.9978081583976746}]
# [{'label': 'NEGATIVE', 'score': 0.9994975328445435}]
# [{'label': 'POSITIVE', 'score': 0.998796820640564}]
# [{'label': 'NEGATIVE', 'score': 0.9994515776634216}]
# [{'label': 'NEGATIVE', 'score': 0.9978907704353333}]
# [{'label': 'NEGATIVE', 'score': 0.9994749426841736}]
# [{'label': 'POSITIVE', 'score': 0.9979448914527893}]
# [{'label': 'NEGATIVE', 'score': 0.9394934177398682}]
# [{'label': 'NEGATIVE', 'score': 0.9994469285011292}]
# [{'label': 'POSITIVE', 'score': 0.9930805563926697}]
# [{'label': 'POSITIVE', 'score': 0.9965941309928894}]
# [{'label': 'POSITIVE', 'score': 0.9986081719398499}]
# [{'label': 'POSITIVE', 'score': 0.9466850161552429}]
# [{'label': 'NEGATIVE', 'score': 0.9994856119155884}]
# [{'label': 'POSITIVE', 'score': 0.9966409206390381}]
# [{'label': 'NEGATIVE', 'score': 0.9993528723716736}]
# [{'label': 'NEGATIVE', 'score': 0.9991663694381714}]
# [{'label': 'NEGATIVE', 'score': 0.9916274547576904}]
# [{'label': 'POSITIVE', 'score': 0.9876791834831238}]
# [{'label': 'NEGATIVE', 'score': 0.9922701120376587}]
# [{'label': 'NEGATIVE', 'score': 0.9994392991065979}]
# [{'label': 'NEGATIVE', 'score': 0.9942252039909363}]
# [{'label': 'POSITIVE', 'score': 0.9809653162956238}]
# [{'label': 'POSITIVE', 'score': 0.9978861212730408}]
# [{'label': 'POSITIVE', 'score': 0.9953591227531433}]
# [{'label': 'NEGATIVE', 'score': 0.9994012117385864}]
# [{'label': 'POSITIVE', 'score': 0.9977276921272278}]
# [{'label': 'NEGATIVE', 'score': 0.5496640205383301}]
# [{'label': 'POSITIVE', 'score': 0.9976857900619507}]
# [{'label': 'NEGATIVE', 'score': 0.9994786381721497}]
# [{'label': 'NEGATIVE', 'score': 0.9993833303451538}]
# [{'label': 'NEGATIVE', 'score': 0.9934424161911011}]
# [{'label': 'NEGATIVE', 'score': 0.9925727844238281}]
# [{'label': 'NEGATIVE', 'score': 0.9995002746582031}]
# [{'label': 'NEGATIVE', 'score': 0.9992066025733948}]
# [{'label': 'NEGATIVE', 'score': 0.9995018243789673}]
# [{'label': 'NEGATIVE', 'score': 0.9968661665916443}]
# [{'label': 'NEGATIVE', 'score': 0.9994999170303345}]
# [{'label': 'NEGATIVE', 'score': 0.9853698015213013}]
# [{'label': 'NEGATIVE', 'score': 0.9990965127944946}]
# [{'label': 'NEGATIVE', 'score': 0.9994820952415466}]
# [{'label': 'NEGATIVE', 'score': 0.9994113445281982}]
# [{'label': 'NEGATIVE', 'score': 0.9983037710189819}]
# [{'label': 'NEGATIVE', 'score': 0.998256266117096}]
# [{'label': 'POSITIVE', 'score': 0.9985373020172119}]
# [{'label': 'NEGATIVE', 'score': 0.9993675351142883}]
# [{'label': 'POSITIVE', 'score': 0.9983384609222412}]
# [{'label': 'POSITIVE', 'score': 0.996455192565918}]
# [{'label': 'NEGATIVE', 'score': 0.9988465309143066}]
# [{'label': 'NEGATIVE', 'score': 0.9985491633415222}]
# [{'label': 'POSITIVE', 'score': 0.9850478172302246}]
# [{'label': 'POSITIVE', 'score': 0.9974557757377625}]
# [{'label': 'NEGATIVE', 'score': 0.9987508058547974}]
# [{'label': 'POSITIVE', 'score': 0.998231828212738}]
# [{'label': 'NEGATIVE', 'score': 0.9986326098442078}]
# [{'label': 'NEGATIVE', 'score': 0.9988712668418884}]
# [{'label': 'NEGATIVE', 'score': 0.9988792538642883}]
# [{'label': 'NEGATIVE', 'score': 0.9990345239639282}]
# [{'label': 'NEGATIVE', 'score': 0.9994698166847229}]
# [{'label': 'NEGATIVE', 'score': 0.9994938373565674}]
# [{'label': 'POSITIVE', 'score': 0.9898243546485901}]
# [{'label': 'POSITIVE', 'score': 0.987809419631958}]
# [{'label': 'NEGATIVE', 'score': 0.9988424181938171}]
# [{'label': 'NEGATIVE', 'score': 0.9994644522666931}]
# [{'label': 'NEGATIVE', 'score': 0.9919746518135071}]
# [{'label': 'POSITIVE', 'score': 0.9986647367477417}]
# [{'label': 'NEGATIVE', 'score': 0.9994668364524841}]
# [{'label': 'POSITIVE', 'score': 0.9969608187675476}]
# [{'label': 'NEGATIVE', 'score': 0.9994762539863586}]
# [{'label': 'NEGATIVE', 'score': 0.9900006055831909}]
# [{'label': 'NEGATIVE', 'score': 0.9994810223579407}]
# [{'label': 'POSITIVE', 'score': 0.9937151074409485}]
# [{'label': 'POSITIVE', 'score': 0.9985030889511108}]
# [{'label': 'NEGATIVE', 'score': 0.9977772831916809}]
# [{'label': 'POSITIVE', 'score': 0.9945163130760193}]
# [{'label': 'NEGATIVE', 'score': 0.994307816028595}]
# [{'label': 'POSITIVE', 'score': 0.9983425140380859}]
# [{'label': 'POSITIVE', 'score': 0.9768117070198059}]
# [{'label': 'POSITIVE', 'score': 0.9984440207481384}]
# [{'label': 'POSITIVE', 'score': 0.9943438768386841}]
# [{'label': 'POSITIVE', 'score': 0.9988370537757874}]
# [{'label': 'NEGATIVE', 'score': 0.9977278113365173}]
# [{'label': 'POSITIVE', 'score': 0.998428463935852}]
# [{'label': 'NEGATIVE', 'score': 0.9922296404838562}]
# [{'label': 'POSITIVE', 'score': 0.9987013339996338}]
# [{'label': 'POSITIVE', 'score': 0.9926729798316956}]
# [{'label': 'NEGATIVE', 'score': 0.9928390383720398}]
# [{'label': 'POSITIVE', 'score': 0.9965963959693909}]
# [{'label': 'POSITIVE', 'score': 0.9982688426971436}]
# [{'label': 'POSITIVE', 'score': 0.9987655878067017}]
# [{'label': 'POSITIVE', 'score': 0.9981258511543274}]
# [{'label': 'NEGATIVE', 'score': 0.9937764406204224}]
# [{'label': 'POSITIVE', 'score': 0.9967281818389893}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'POSITIVE', 'score': 0.9974167346954346}]
# [{'label': 'POSITIVE', 'score': 0.996484637260437}]
# [{'label': 'NEGATIVE', 'score': 0.999495267868042}]
# [{'label': 'POSITIVE', 'score': 0.9979902505874634}]
# [{'label': 'NEGATIVE', 'score': 0.993664026260376}]
# [{'label': 'NEGATIVE', 'score': 0.984154462814331}]
# [{'label': 'POSITIVE', 'score': 0.9975292086601257}]
# [{'label': 'POSITIVE', 'score': 0.9972015619277954}]
# [{'label': 'POSITIVE', 'score': 0.9979800581932068}]
# [{'label': 'POSITIVE', 'score': 0.9872165322303772}]
# [{'label': 'NEGATIVE', 'score': 0.9916644096374512}]
# [{'label': 'POSITIVE', 'score': 0.9577817320823669}]
# [{'label': 'POSITIVE', 'score': 0.9872363209724426}]
# [{'label': 'POSITIVE', 'score': 0.9988716244697571}]
# [{'label': 'POSITIVE', 'score': 0.9950569868087769}]
# [{'label': 'POSITIVE', 'score': 0.9985346794128418}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'POSITIVE', 'score': 0.9987548589706421}]
# [{'label': 'POSITIVE', 'score': 0.9962426424026489}]
# [{'label': 'POSITIVE', 'score': 0.9963786005973816}]
# [{'label': 'POSITIVE', 'score': 0.9974683523178101}]
# [{'label': 'POSITIVE', 'score': 0.9967869520187378}]
# [{'label': 'NEGATIVE', 'score': 0.9696757793426514}]
# [{'label': 'NEGATIVE', 'score': 0.9965862035751343}]
# [{'label': 'POSITIVE', 'score': 0.9987106323242188}]
# [{'label': 'NEGATIVE', 'score': 0.9902875423431396}]
# [{'label': 'POSITIVE', 'score': 0.9629316329956055}]
# [{'label': 'POSITIVE', 'score': 0.9977007508277893}]
# [{'label': 'POSITIVE', 'score': 0.998747706413269}]
# [{'label': 'NEGATIVE', 'score': 0.9911927580833435}]
# [{'label': 'NEGATIVE', 'score': 0.9865552186965942}]
# [{'label': 'POSITIVE', 'score': 0.9775274991989136}]
# [{'label': 'NEGATIVE', 'score': 0.9985300302505493}]
# [{'label': 'POSITIVE', 'score': 0.9884936213493347}]
# [{'label': 'POSITIVE', 'score': 0.998189389705658}]
# [{'label': 'POSITIVE', 'score': 0.9822009205818176}]
# [{'label': 'POSITIVE', 'score': 0.9968940019607544}]
# [{'label': 'POSITIVE', 'score': 0.9899349808692932}]
# [{'label': 'POSITIVE', 'score': 0.9933265447616577}]
# [{'label': 'NEGATIVE', 'score': 0.9974907636642456}]
# [{'label': 'NEGATIVE', 'score': 0.9988180994987488}]
# [{'label': 'POSITIVE', 'score': 0.985903799533844}]
# [{'label': 'POSITIVE', 'score': 0.9981992840766907}]
# [{'label': 'POSITIVE', 'score': 0.9911598563194275}]
# [{'label': 'NEGATIVE', 'score': 0.9994342923164368}]
# [{'label': 'NEGATIVE', 'score': 0.9958639144897461}]
# [{'label': 'POSITIVE', 'score': 0.998426079750061}]
# [{'label': 'POSITIVE', 'score': 0.9979554414749146}]
# [{'label': 'POSITIVE', 'score': 0.998218834400177}]
# [{'label': 'POSITIVE', 'score': 0.9974623918533325}]
# [{'label': 'POSITIVE', 'score': 0.9983540773391724}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'POSITIVE', 'score': 0.9968940019607544}]
# [{'label': 'POSITIVE', 'score': 0.9985232949256897}]
# [{'label': 'POSITIVE', 'score': 0.9814980626106262}]
# [{'label': 'POSITIVE', 'score': 0.9972320199012756}]
# [{'label': 'POSITIVE', 'score': 0.8098522424697876}]
# [{'label': 'POSITIVE', 'score': 0.9964348077774048}]
# [{'label': 'POSITIVE', 'score': 0.7931820750236511}]
# [{'label': 'POSITIVE', 'score': 0.9922522902488708}]
# [{'label': 'POSITIVE', 'score': 0.9563247561454773}]
# [{'label': 'POSITIVE', 'score': 0.9947998523712158}]
# [{'label': 'POSITIVE', 'score': 0.9988113641738892}]
# [{'label': 'POSITIVE', 'score': 0.9988102912902832}]
# [{'label': 'NEGATIVE', 'score': 0.9993415474891663}]
# [{'label': 'POSITIVE', 'score': 0.9920997023582458}]
# [{'label': 'POSITIVE', 'score': 0.9973596930503845}]
# [{'label': 'POSITIVE', 'score': 0.9945934414863586}]
# [{'label': 'NEGATIVE', 'score': 0.9988328814506531}]
# [{'label': 'NEGATIVE', 'score': 0.9994848966598511}]
# [{'label': 'POSITIVE', 'score': 0.9987014532089233}]
# [{'label': 'NEGATIVE', 'score': 0.9955816864967346}]
# [{'label': 'POSITIVE', 'score': 0.9975027441978455}]
# [{'label': 'POSITIVE', 'score': 0.9652430415153503}]
# [{'label': 'POSITIVE', 'score': 0.9969600439071655}]
# [{'label': 'POSITIVE', 'score': 0.9854583740234375}]
# [{'label': 'NEGATIVE', 'score': 0.9994257688522339}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'POSITIVE', 'score': 0.9863796830177307}]
# [{'label': 'NEGATIVE', 'score': 0.9950213432312012}]
# [{'label': 'NEGATIVE', 'score': 0.991134762763977}]
# [{'label': 'POSITIVE', 'score': 0.9984585046768188}]
# [{'label': 'POSITIVE', 'score': 0.9559820890426636}]
# [{'label': 'NEGATIVE', 'score': 0.9908257126808167}]
# [{'label': 'POSITIVE', 'score': 0.9982163310050964}]
# [{'label': 'NEGATIVE', 'score': 0.999229907989502}]
# [{'label': 'POSITIVE', 'score': 0.9950060248374939}]
# [{'label': 'NEGATIVE', 'score': 0.9980834722518921}]
# [{'label': 'POSITIVE', 'score': 0.9980196952819824}]
# [{'label': 'POSITIVE', 'score': 0.9723366498947144}]
# [{'label': 'NEGATIVE', 'score': 0.9976165294647217}]
# [{'label': 'NEGATIVE', 'score': 0.9982728958129883}]
# [{'label': 'POSITIVE', 'score': 0.9867086410522461}]
# [{'label': 'POSITIVE', 'score': 0.9917028546333313}]
# [{'label': 'POSITIVE', 'score': 0.9869990944862366}]
# [{'label': 'POSITIVE', 'score': 0.9953882694244385}]
# [{'label': 'POSITIVE', 'score': 0.9794856309890747}]
# [{'label': 'POSITIVE', 'score': 0.9822009205818176}]
# [{'label': 'NEGATIVE', 'score': 0.9814770817756653}]
# [{'label': 'NEGATIVE', 'score': 0.9860849380493164}]
# [{'label': 'POSITIVE', 'score': 0.9978984594345093}]
# [{'label': 'POSITIVE', 'score': 0.9972729086875916}]
# [{'label': 'POSITIVE', 'score': 0.9920303821563721}]
# [{'label': 'NEGATIVE', 'score': 0.9909204244613647}]
# [{'label': 'POSITIVE', 'score': 0.9924231767654419}]
# [{'label': 'POSITIVE', 'score': 0.9970659613609314}]
# [{'label': 'POSITIVE', 'score': 0.9986435770988464}]
# [{'label': 'NEGATIVE', 'score': 0.9990589022636414}]
# [{'label': 'POSITIVE', 'score': 0.981151282787323}]
# [{'label': 'NEGATIVE', 'score': 0.9988313317298889}]
# [{'label': 'NEGATIVE', 'score': 0.9994645714759827}]
# [{'label': 'NEGATIVE', 'score': 0.9977163076400757}]
# [{'label': 'POSITIVE', 'score': 0.998648464679718}]
# [{'label': 'POSITIVE', 'score': 0.9015823602676392}]
# [{'label': 'NEGATIVE', 'score': 0.8982580304145813}]
# [{'label': 'POSITIVE', 'score': 0.9980872273445129}]
# [{'label': 'NEGATIVE', 'score': 0.9909204244613647}]
# [{'label': 'POSITIVE', 'score': 0.9987809062004089}]
# [{'label': 'POSITIVE', 'score': 0.9984021782875061}]
# [{'label': 'POSITIVE', 'score': 0.9636343717575073}]
# [{'label': 'NEGATIVE', 'score': 0.9978081583976746}]
# [{'label': 'POSITIVE', 'score': 0.9629316329956055}]
# [{'label': 'POSITIVE', 'score': 0.9978253841400146}]
# [{'label': 'POSITIVE', 'score': 0.9980559349060059}]
# [{'label': 'POSITIVE', 'score': 0.9976207613945007}]
# [{'label': 'POSITIVE', 'score': 0.9976950287818909}]
# [{'label': 'POSITIVE', 'score': 0.9875653386116028}]
# [{'label': 'NEGATIVE', 'score': 0.9983187913894653}]
# [{'label': 'POSITIVE', 'score': 0.9925014972686768}]
# [{'label': 'POSITIVE', 'score': 0.9541401267051697}]
# [{'label': 'POSITIVE', 'score': 0.9972168207168579}]
# [{'label': 'POSITIVE', 'score': 0.9947007894515991}]
# [{'label': 'POSITIVE', 'score': 0.9968603849411011}]
# [{'label': 'POSITIVE', 'score': 0.9982886910438538}]
# [{'label': 'POSITIVE', 'score': 0.9977450370788574}]
# [{'label': 'POSITIVE', 'score': 0.9986183643341064}]
# [{'label': 'POSITIVE', 'score': 0.9984305500984192}]
# [{'label': 'NEGATIVE', 'score': 0.9951488375663757}]
# [{'label': 'POSITIVE', 'score': 0.9987550973892212}]
# [{'label': 'POSITIVE', 'score': 0.9894318580627441}]
# [{'label': 'NEGATIVE', 'score': 0.9943970441818237}]
# [{'label': 'NEGATIVE', 'score': 0.9994458556175232}]
# [{'label': 'NEGATIVE', 'score': 0.982530415058136}]
# [{'label': 'POSITIVE', 'score': 0.9374150633811951}]
# [{'label': 'POSITIVE', 'score': 0.993611752986908}]
# [{'label': 'POSITIVE', 'score': 0.9965307116508484}]
# [{'label': 'POSITIVE', 'score': 0.9978972673416138}]
# [{'label': 'NEGATIVE', 'score': 0.9994822144508362}]
# [{'label': 'POSITIVE', 'score': 0.990314781665802}]
# [{'label': 'POSITIVE', 'score': 0.9946053624153137}]
# [{'label': 'POSITIVE', 'score': 0.9890166521072388}]
# [{'label': 'NEGATIVE', 'score': 0.9910767078399658}]
# [{'label': 'POSITIVE', 'score': 0.998417854309082}]
# [{'label': 'POSITIVE', 'score': 0.9854889512062073}]
# [{'label': 'NEGATIVE', 'score': 0.9688952565193176}]
# ...
# [{'label': 'NEGATIVE', 'score': 0.9973378777503967}]
# [{'label': 'POSITIVE', 'score': 0.9975085258483887}]
# [{'label': 'POSITIVE', 'score': 0.9978427886962891}]
# [{'label': 'POSITIVE', 'score': 0.9971720576286316}]
# [{'label': 'NEGATIVE', 'score': 0.9979032278060913}]
# [{'label': 'NEGATIVE', 'score': 0.9927183389663696}]
# [{'label': 'NEGATIVE', 'score': 0.9977523684501648}]
# [{'label': 'POSITIVE', 'score': 0.9986453652381897}]
# [{'label': 'POSITIVE', 'score': 0.9960700273513794}]
# [{'label': 'POSITIVE', 'score': 0.9975911378860474}]
# [{'label': 'NEGATIVE', 'score': 0.9994767308235168}]
# [{'label': 'POSITIVE', 'score': 0.9981293082237244}]
# [{'label': 'NEGATIVE', 'score': 0.9992151260375977}]
# [{'label': 'POSITIVE', 'score': 0.9984694123268127}]
# [{'label': 'NEGATIVE', 'score': 0.9988738894462585}]
# [{'label': 'POSITIVE', 'score': 0.9914485812187195}]
# [{'label': 'POSITIVE', 'score': 0.9983066320419312}]
# [{'label': 'NEGATIVE', 'score': 0.9354169964790344}]
# [{'label': 'POSITIVE', 'score': 0.9971829652786255}]
# [{'label': 'NEGATIVE', 'score': 0.9908590912818909}]
# [{'label': 'POSITIVE', 'score': 0.9842989444732666}]
# [{'label': 'POSITIVE', 'score': 0.9961881041526794}]
# [{'label': 'POSITIVE', 'score': 0.9868791699409485}]
# [{'label': 'NEGATIVE', 'score': 0.9814302325248718}]
# [{'label': 'POSITIVE', 'score': 0.9400001168251038}]
# [{'label': 'POSITIVE', 'score': 0.9963088631629944}]
# [{'label': 'NEGATIVE', 'score': 0.9987971782684326}]
# [{'label': 'POSITIVE', 'score': 0.9096156358718872}]
# [{'label': 'POSITIVE', 'score': 0.998630702495575}]
# [{'label': 'NEGATIVE', 'score': 0.9988526105880737}]
# [{'label': 'POSITIVE', 'score': 0.9984138011932373}]
# [{'label': 'POSITIVE', 'score': 0.9926446676254272}]
# [{'label': 'NEGATIVE', 'score': 0.9876548647880554}]
# [{'label': 'POSITIVE', 'score': 0.9977534413337708}]
# [{'label': 'POSITIVE', 'score': 0.9979450106620789}]
# [{'label': 'NEGATIVE', 'score': 0.9938393235206604}]
# [{'label': 'NEGATIVE', 'score': 0.9990118741989136}]
# [{'label': 'POSITIVE', 'score': 0.9985288381576538}]
# [{'label': 'POSITIVE', 'score': 0.9845635890960693}]
# [{'label': 'POSITIVE', 'score': 0.993353009223938}]
# [{'label': 'POSITIVE', 'score': 0.998630702495575}]
# [{'label': 'POSITIVE', 'score': 0.9967530369758606}]
# [{'label': 'POSITIVE', 'score': 0.9878135919570923}]
# [{'label': 'POSITIVE', 'score': 0.9983392953872681}]
# [{'label': 'POSITIVE', 'score': 0.9982709884643555}]
# [{'label': 'POSITIVE', 'score': 0.8598157167434692}]
# [{'label': 'POSITIVE', 'score': 0.9958891272544861}]
# [{'label': 'NEGATIVE', 'score': 0.9962537288665771}]
# [{'label': 'NEGATIVE', 'score': 0.9987585544586182}]
# [{'label': 'NEGATIVE', 'score': 0.991319477558136}]
# [{'label': 'NEGATIVE', 'score': 0.9961684346199036}]
# [{'label': 'NEGATIVE', 'score': 0.9962073564529419}]
# [{'label': 'NEGATIVE', 'score': 0.9866214990615845}]
# [{'label': 'NEGATIVE', 'score': 0.9852409958839417}]
# [{'label': 'POSITIVE', 'score': 0.9982017278671265}]
# [{'label': 'NEGATIVE', 'score': 0.9903537034988403}]
# [{'label': 'POSITIVE', 'score': 0.9977668523788452}]
# [{'label': 'POSITIVE', 'score': 0.986101508140564}]
# [{'label': 'POSITIVE', 'score': 0.9970820546150208}]
# [{'label': 'POSITIVE', 'score': 0.9959020018577576}]
# [{'label': 'POSITIVE', 'score': 0.9952844977378845}]
# [{'label': 'NEGATIVE', 'score': 0.9726352095603943}]
# [{'label': 'POSITIVE', 'score': 0.9967818260192871}]
# [{'label': 'POSITIVE', 'score': 0.9985914826393127}]
# [{'label': 'POSITIVE', 'score': 0.991032063961029}]
# [{'label': 'POSITIVE', 'score': 0.9968770742416382}]
# [{'label': 'NEGATIVE', 'score': 0.9915956854820251}]
# [{'label': 'NEGATIVE', 'score': 0.9989758729934692}]
# [{'label': 'POSITIVE', 'score': 0.9734111428260803}]
# [{'label': 'POSITIVE', 'score': 0.9932865500450134}]
# [{'label': 'NEGATIVE', 'score': 0.9964500665664673}]
# [{'label': 'POSITIVE', 'score': 0.9928233623504639}]
# [{'label': 'POSITIVE', 'score': 0.9869654178619385}]
# [{'label': 'POSITIVE', 'score': 0.9979346990585327}]
# [{'label': 'NEGATIVE', 'score': 0.9905463457107544}]
# [{'label': 'POSITIVE', 'score': 0.9941607117652893}]
# [{'label': 'NEGATIVE', 'score': 0.9867702722549438}]
# [{'label': 'POSITIVE', 'score': 0.9826687574386597}]
# [{'label': 'POSITIVE', 'score': 0.9961766004562378}]
# [{'label': 'POSITIVE', 'score': 0.998433530330658}]
# [{'label': 'POSITIVE', 'score': 0.9723336100578308}]
# [{'label': 'POSITIVE', 'score': 0.9957695007324219}]
# [{'label': 'POSITIVE', 'score': 0.9979881048202515}]
# [{'label': 'POSITIVE', 'score': 0.9906438589096069}]
# [{'label': 'POSITIVE', 'score': 0.9984588623046875}]
# [{'label': 'POSITIVE', 'score': 0.9973006844520569}]
# [{'label': 'NEGATIVE', 'score': 0.9930918216705322}]
# [{'label': 'POSITIVE', 'score': 0.993934690952301}]
# [{'label': 'NEGATIVE', 'score': 0.9994308352470398}]
# [{'label': 'POSITIVE', 'score': 0.9711592197418213}]
# [{'label': 'NEGATIVE', 'score': 0.9956945180892944}]
# [{'label': 'POSITIVE', 'score': 0.9917839765548706}]
# [{'label': 'NEGATIVE', 'score': 0.9958986639976501}]
# [{'label': 'NEGATIVE', 'score': 0.9931018352508545}]
# [{'label': 'NEGATIVE', 'score': 0.8112719058990479}]
# [{'label': 'POSITIVE', 'score': 0.9948078989982605}]
# [{'label': 'NEGATIVE', 'score': 0.9938675761222839}]
# [{'label': 'POSITIVE', 'score': 0.998233437538147}]
# [{'label': 'POSITIVE', 'score': 0.9982490539550781}]
# [{'label': 'NEGATIVE', 'score': 0.9974139928817749}]
# [{'label': 'POSITIVE', 'score': 0.9823873043060303}]
# [{'label': 'POSITIVE', 'score': 0.9984790682792664}]
# [{'label': 'NEGATIVE', 'score': 0.9981898665428162}]
# [{'label': 'POSITIVE', 'score': 0.9970206618309021}]
# [{'label': 'POSITIVE', 'score': 0.9943312406539917}]
# [{'label': 'NEGATIVE', 'score': 0.9877350926399231}]
# [{'label': 'NEGATIVE', 'score': 0.9824460744857788}]
# [{'label': 'NEGATIVE', 'score': 0.99552983045578}]
# [{'label': 'NEGATIVE', 'score': 0.9853315353393555}]
# [{'label': 'POSITIVE', 'score': 0.9885066747665405}]
# [{'label': 'NEGATIVE', 'score': 0.9914464950561523}]
# [{'label': 'NEGATIVE', 'score': 0.993696391582489}]
# [{'label': 'POSITIVE', 'score': 0.9981812238693237}]
# [{'label': 'NEGATIVE', 'score': 0.9981184005737305}]
# [{'label': 'POSITIVE', 'score': 0.9787716865539551}]
# [{'label': 'POSITIVE', 'score': 0.9912382960319519}]
# [{'label': 'POSITIVE', 'score': 0.9960511326789856}]
# [{'label': 'POSITIVE', 'score': 0.9977439641952515}]
# [{'label': 'POSITIVE', 'score': 0.9969135522842407}]
# [{'label': 'NEGATIVE', 'score': 0.9978112578392029}]
# [{'label': 'POSITIVE', 'score': 0.9929961562156677}]
# [{'label': 'NEGATIVE', 'score': 0.9967772364616394}]
# [{'label': 'POSITIVE', 'score': 0.9983166456222534}]
# [{'label': 'NEGATIVE', 'score': 0.9956207871437073}]
# [{'label': 'POSITIVE', 'score': 0.9985998272895813}]
# [{'label': 'POSITIVE', 'score': 0.9832416772842407}]
# [{'label': 'NEGATIVE', 'score': 0.9950662851333618}]
# [{'label': 'NEGATIVE', 'score': 0.9864729642868042}]
# [{'label': 'NEGATIVE', 'score': 0.9451271891593933}]
# [{'label': 'NEGATIVE', 'score': 0.9992839694023132}]
# [{'label': 'POSITIVE', 'score': 0.9983370304107666}]
# [{'label': 'POSITIVE', 'score': 0.9984368681907654}]
# [{'label': 'POSITIVE', 'score': 0.9865213632583618}]
# [{'label': 'NEGATIVE', 'score': 0.9941206574440002}]
# [{'label': 'NEGATIVE', 'score': 0.9987496137619019}]
# [{'label': 'POSITIVE', 'score': 0.9892879724502563}]
# [{'label': 'POSITIVE', 'score': 0.9959957599639893}]
# [{'label': 'NEGATIVE', 'score': 0.9907991290092468}]
# [{'label': 'POSITIVE', 'score': 0.9969944953918457}]
# [{'label': 'POSITIVE', 'score': 0.799119770526886}]
# [{'label': 'NEGATIVE', 'score': 0.9984464049339294}]
# [{'label': 'NEGATIVE', 'score': 0.9933238625526428}]
# [{'label': 'NEGATIVE', 'score': 0.9986696243286133}]
# [{'label': 'POSITIVE', 'score': 0.9792694449424744}]
# [{'label': 'NEGATIVE', 'score': 0.9605488777160645}]
# [{'label': 'POSITIVE', 'score': 0.9839023947715759}]
# [{'label': 'POSITIVE', 'score': 0.9975875616073608}]
# [{'label': 'POSITIVE', 'score': 0.9962226152420044}]
# [{'label': 'POSITIVE', 'score': 0.9972561001777649}]
# [{'label': 'POSITIVE', 'score': 0.9833804368972778}]
# [{'label': 'NEGATIVE', 'score': 0.9913951754570007}]
# [{'label': 'NEGATIVE', 'score': 0.9920461177825928}]
# [{'label': 'POSITIVE', 'score': 0.9973510503768921}]
# [{'label': 'POSITIVE', 'score': 0.9876420497894287}]
# [{'label': 'POSITIVE', 'score': 0.9929078817367554}]
# [{'label': 'NEGATIVE', 'score': 0.9953166246414185}]
# [{'label': 'POSITIVE', 'score': 0.9966230392456055}]
# [{'label': 'NEGATIVE', 'score': 0.9869340658187866}]
# [{'label': 'POSITIVE', 'score': 0.9957155585289001}]
# [{'label': 'NEGATIVE', 'score': 0.9942998886108398}]
# [{'label': 'NEGATIVE', 'score': 0.9888838529586792}]
# [{'label': 'POSITIVE', 'score': 0.9967870712280273}]
# [{'label': 'NEGATIVE', 'score': 0.9979493021965027}]
# [{'label': 'POSITIVE', 'score': 0.9938241243362427}]
# [{'label': 'POSITIVE', 'score': 0.9830322265625}]
# [{'label': 'POSITIVE', 'score': 0.9980630278587341}]
# [{'label': 'POSITIVE', 'score': 0.998161256313324}]
# [{'label': 'POSITIVE', 'score': 0.9922730326652527}]
# [{'label': 'POSITIVE', 'score': 0.9982434511184692}]
# [{'label': 'POSITIVE', 'score': 0.9987491369247437}]
# [{'label': 'POSITIVE', 'score': 0.9979598522186279}]
# [{'label': 'NEGATIVE', 'score': 0.9946974515914917}]
# [{'label': 'NEGATIVE', 'score': 0.9876000881195068}]
# [{'label': 'POSITIVE', 'score': 0.9958048462867737}]
# [{'label': 'POSITIVE', 'score': 0.9987354874610901}]
# [{'label': 'POSITIVE', 'score': 0.9985191226005554}]
# [{'label': 'NEGATIVE', 'score': 0.993166983127594}]
# [{'label': 'POSITIVE', 'score': 0.9966211318969727}]
# [{'label': 'POSITIVE', 'score': 0.9863082766532898}]
# [{'label': 'POSITIVE', 'score': 0.9976804256439209}]
# [{'label': 'POSITIVE', 'score': 0.9858042001724243}]
# [{'label': 'POSITIVE', 'score': 0.9980481863021851}]
# [{'label': 'NEGATIVE', 'score': 0.997423529624939}]
# [{'label': 'POSITIVE', 'score': 0.9980269074440002}]
# [{'label': 'NEGATIVE', 'score': 0.9949324727058411}]
# [{'label': 'NEGATIVE', 'score': 0.9964978098869324}]
# [{'label': 'POSITIVE', 'score': 0.9955867528915405}]
# [{'label': 'NEGATIVE', 'score': 0.5075382590293884}]
# [{'label': 'NEGATIVE', 'score': 0.9981911778450012}]
# [{'label': 'POSITIVE', 'score': 0.9948215484619141}]
# [{'label': 'NEGATIVE', 'score': 0.9949169158935547}]
# [{'label': 'NEGATIVE', 'score': 0.990345299243927}]
# [{'label': 'NEGATIVE', 'score': 0.9882528185844421}]
# [{'label': 'POSITIVE', 'score': 0.9854078888893127}]
# [{'label': 'POSITIVE', 'score': 0.9977012276649475}]
# [{'label': 'POSITIVE', 'score': 0.9933033585548401}]
# [{'label': 'POSITIVE', 'score': 0.9979470372200012}]
# [{'label': 'NEGATIVE', 'score': 0.9735065698623657}]
# [{'label': 'POSITIVE', 'score': 0.9978790283203125}]
# [{'label': 'NEGATIVE', 'score': 0.9852409958839417}]
# [{'label': 'POSITIVE', 'score': 0.9983671307563782}]
# [{'label': 'POSITIVE', 'score': 0.9956526756286621}]
# [{'label': 'POSITIVE', 'score': 0.9967708587646484}]
# [{'label': 'POSITIVE', 'score': 0.9984986782073975}]
# [{'label': 'POSITIVE', 'score': 0.9860471487045288}]
# [{'label': 'POSITIVE', 'score': 0.9964042901992798}]
# [{'label': 'POSITIVE', 'score': 0.9929313659667969}]
# [{'label': 'NEGATIVE', 'score': 0.9867405295372009}]
# [{'label': 'NEGATIVE', 'score': 0.9933018684387207}]
# [{'label': 'POSITIVE', 'score': 0.9979099631309509}]
# [{'label': 'POSITIVE', 'score': 0.9986653327941895}]
# [{'label': 'NEGATIVE', 'score': 0.9889166355133057}]
# [{'label': 'NEGATIVE', 'score': 0.9990354776382446}]
# [{'label': 'POSITIVE', 'score': 0.9955924153327942}]
# [{'label': 'NEGATIVE', 'score': 0.9549580216407776}]
# [{'label': 'POSITIVE', 'score': 0.9928544163703918}]
# [{'label': 'NEGATIVE', 'score': 0.9947307109832764}]
# [{'label': 'NEGATIVE', 'score': 0.9933892488479614}]
# [{'label': 'POSITIVE', 'score': 0.9955969452857971}]
# [{'label': 'NEGATIVE', 'score': 0.9588045477867126}]
# [{'label': 'NEGATIVE', 'score': 0.9913111925125122}]
# [{'label': 'NEGATIVE', 'score': 0.9894639253616333}]
# [{'label': 'POSITIVE', 'score': 0.9984037280082703}]
# [{'label': 'NEGATIVE', 'score': 0.9954854846000671}]
# [{'label': 'NEGATIVE', 'score': 0.9714345335960388}]
# [{'label': 'POSITIVE', 'score': 0.9947709441184998}]
# [{'label': 'POSITIVE', 'score': 0.994672954082489}]
# [{'label': 'NEGATIVE', 'score': 0.5638706684112549}]
# [{'label': 'NEGATIVE', 'score': 0.9803891777992249}]
# [{'label': 'POSITIVE', 'score': 0.9943121671676636}]
# [{'label': 'POSITIVE', 'score': 0.9980674386024475}]
# [{'label': 'POSITIVE', 'score': 0.9950591325759888}]
# [{'label': 'NEGATIVE', 'score': 0.988795280456543}]
# [{'label': 'NEGATIVE', 'score': 0.988771378993988}]
# [{'label': 'NEGATIVE', 'score': 0.9917287230491638}]
# [{'label': 'POSITIVE', 'score': 0.9900838136672974}]
# [{'label': 'NEGATIVE', 'score': 0.9976523518562317}]
# [{'label': 'NEGATIVE', 'score': 0.9362112283706665}]
# [{'label': 'POSITIVE', 'score': 0.9980106949806213}]
# [{'label': 'POSITIVE', 'score': 0.9976400136947632}]
# [{'label': 'NEGATIVE', 'score': 0.9882574677467346}]
# [{'label': 'POSITIVE', 'score': 0.9576444029808044}]
# [{'label': 'POSITIVE', 'score': 0.9976961016654968}]
# [{'label': 'POSITIVE', 'score': 0.9947709441184998}]
# [{'label': 'NEGATIVE', 'score': 0.9959314465522766}]
# [{'label': 'NEGATIVE', 'score': 0.9792791604995728}]
# [{'label': 'NEGATIVE', 'score': 0.9948261380195618}]
# [{'label': 'POSITIVE', 'score': 0.9834735989570618}]
# [{'label': 'NEGATIVE', 'score': 0.9983342289924622}]
# [{'label': 'NEGATIVE', 'score': 0.9853307008743286}]
# [{'label': 'POSITIVE', 'score': 0.9923457503318787}]
# [{'label': 'POSITIVE', 'score': 0.9972992539405823}]
# [{'label': 'NEGATIVE', 'score': 0.9603391885757446}]
# [{'label': 'POSITIVE', 'score': 0.9906026124954224}]
# [{'label': 'NEGATIVE', 'score': 0.9941217303276062}]
# [{'label': 'POSITIVE', 'score': 0.9505890607833862}]
# [{'label': 'POSITIVE', 'score': 0.9398918151855469}]
# [{'label': 'POSITIVE', 'score': 0.9687466621398926}]
# [{'label': 'POSITIVE', 'score': 0.9839769601821899}]
# [{'label': 'POSITIVE', 'score': 0.9911051392555237}]
# [{'label': 'POSITIVE', 'score': 0.9975811243057251}]
# [{'label': 'POSITIVE', 'score': 0.9960805773735046}]
# [{'label': 'POSITIVE', 'score': 0.9986685514450073}]
# [{'label': 'NEGATIVE', 'score': 0.9913314580917358}]
# [{'label': 'POSITIVE', 'score': 0.9988143444061279}]
# [{'label': 'POSITIVE', 'score': 0.9984295964241028}]
# [{'label': 'POSITIVE', 'score': 0.9958820343017578}]
# [{'label': 'POSITIVE', 'score': 0.5748937129974365}]
# [{'label': 'POSITIVE', 'score': 0.9983943104743958}]
# [{'label': 'POSITIVE', 'score': 0.9908493757247925}]
# [{'label': 'POSITIVE', 'score': 0.9987311959266663}]
# [{'label': 'NEGATIVE', 'score': 0.9965521097183228}]
# [{'label': 'POSITIVE', 'score': 0.9977527260780334}]
# [{'label': 'POSITIVE', 'score': 0.9985232949256897}]
# [{'label': 'NEGATIVE', 'score': 0.9896161556243896}]
# [{'label': 'NEGATIVE', 'score': 0.965634822845459}]
# [{'label': 'NEGATIVE', 'score': 0.9853436350822449}]
# [{'label': 'POSITIVE', 'score': 0.9985461235046387}]
# [{'label': 'NEGATIVE', 'score': 0.9994469285011292}]
# [{'label': 'NEGATIVE', 'score': 0.6443866491317749}]
# [{'label': 'POSITIVE', 'score': 0.9319717884063721}]
# [{'label': 'POSITIVE', 'score': 0.9982788562774658}]
# [{'label': 'POSITIVE', 'score': 0.9924889802932739}]
# [{'label': 'POSITIVE', 'score': 0.9973059892654419}]
# [{'label': 'NEGATIVE', 'score': 0.996793806552887}]
# [{'label': 'POSITIVE', 'score': 0.9951149225234985}]
# [{'label': 'POSITIVE', 'score': 0.9985306262969971}]
# [{'label': 'POSITIVE', 'score': 0.9979873895645142}]
# [{'label': 'NEGATIVE', 'score': 0.9941605925559998}]
# [{'label': 'POSITIVE', 'score': 0.9873277544975281}]
# [{'label': 'POSITIVE', 'score': 0.9937100410461426}]
# [{'label': 'POSITIVE', 'score': 0.9971839785575867}]
# [{'label': 'NEGATIVE', 'score': 0.9977703094482422}]
# [{'label': 'POSITIVE', 'score': 0.9984777569770813}]
# [{'label': 'POSITIVE', 'score': 0.9974648952484131}]
# [{'label': 'NEGATIVE', 'score': 0.9802574515342712}]
# [{'label': 'POSITIVE', 'score': 0.9974284768104553}]
# [{'label': 'NEGATIVE', 'score': 0.9992075562477112}]
# [{'label': 'POSITIVE', 'score': 0.9852825403213501}]
# [{'label': 'POSITIVE', 'score': 0.9825771450996399}]
# [{'label': 'NEGATIVE', 'score': 0.9822980165481567}]
# [{'label': 'POSITIVE', 'score': 0.9978087544441223}]
# 0.608
